# %% [markdown]
# # BOXPLOT
#
# -  A boxplot is a standardized way of displaying the distribution of data based on a five number summary (“minimum”, first quartile (Q1), median, third quartile (Q3), and “maximum”). It can tell you about your outliers and what their values are. It can also tell you if your data is symmetrical, how tightly your data is grouped, and if and how your data is skewed.

# %% [markdown]
# ![BOXPLOT.png](attachment:BOXPLOT.png)

# %% [markdown]
# **COMPARISON BETWEEN BOXPLOT AND NORMAL DISTRIBUTION PLOT**
#
# ![Box-distribution.png](attachment:Box-distribution.png)

# %%
#Import necessary libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as pe
# %matplotlib inline

# %%
#Cars dataset

# %%
df = pd.read_csv('https://raw.githubusercontent.com/aishwaryamate/Datasets/main/cars.csv')
df
# Out:
#      symboling normalized-losses         make fuel-type   body-style  \
# 0            3                 ?  alfa-romero       gas  convertible
# 1            3                 ?  alfa-romero       gas  convertible
# 2            1                 ?  alfa-romero       gas    hatchback
# 3            2               164         audi       gas        sedan
# 4            2               164         audi       gas        sedan
# ..         ...               ...          ...       ...          ...
# 200         -1                95        volvo       gas        sedan
# 201         -1                95        volvo       gas        sedan
# 202         -1                95        volvo       gas        sedan
# 203         -1                95        volvo    diesel        sedan
# 204         -1                95        volvo       gas        sedan
#
#     drive-wheels engine-location  width  height engine-type  engine-size  \
# 0            rwd           front   64.1    48.8        dohc          130
# 1            rwd           front   64.1    48.8        dohc          130
# 2            rwd           front   65.5    52.4        ohcv          152
# 3            fwd           front   66.2    54.3         ohc          109
# 4            4wd           front   66.4    54.3         ohc          136
# ..           ...             ...    ...     ...         ...          ...
# 200          rwd           front   68.9    55.5         ohc          141
# 201          rwd           front   68.8    55.5         ohc          141
# 202          rwd           front   68.9    55.5        ohcv          173
# 203          rwd           front   68.9    55.5         ohc          145
# 204          rwd           front   68.9    55.5         ohc          141
#
#     horsepower  city-mpg  highway-mpg  price
# 0          111        21           27  13495
# 1          111        21           27  16500
# 2          154        19           26  16500
# 3          102        24           30  13950
# 4          115        18           22  17450
# ..         ...       ...          ...    ...
# 200        114        23           28  16845
# 201        160        19           25  19045
# 202        134        18           23  21485
# 203        106        26           27  22470
# 204        114        19           25  22625
#
# [205 rows x 15 columns]

# %%
#Set the figure size of the graph

# %%
plt.rcParams['figure.figsize'] = (10,5)
plt.rcParams['figure.dpi'] = 250

# %%
df.describe()
# Out:
#         symboling       width      height  engine-size    city-mpg  \
# count  205.000000  205.000000  205.000000   205.000000  205.000000
# mean     0.834146   65.907805   53.724878   126.907317   25.219512
# std      1.245307    2.145204    2.443522    41.642693    6.542142
# min     -2.000000   60.300000   47.800000    61.000000   13.000000
# 25%      0.000000   64.100000   52.000000    97.000000   19.000000
# 50%      1.000000   65.500000   54.100000   120.000000   24.000000
# 75%      2.000000   66.900000   55.500000   141.000000   30.000000
# max      3.000000   72.300000   59.800000   326.000000   49.000000
#
#        highway-mpg         price
# count   205.000000    205.000000
# mean     30.751220  13227.478049
# std       6.886443   7902.651615
# min      16.000000   5118.000000
# 25%      25.000000   7788.000000
# 50%      30.000000  10345.000000
# 75%      34.000000  16500.000000
# max      54.000000  45400.000000

# %%
plt.boxplot(df['width'], vert=False, showmeans=True,notch = True,patch_artist=True)
plt.grid()

# %%
df.boxplot()
# Out:
# <AxesSubplot:>

# %%
plt.boxplot(df['city-mpg'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x288dcdeb4f0>,
#   <matplotlib.lines.Line2D at 0x288dcdeb7f0>],
#  'caps': [<matplotlib.lines.Line2D at 0x288dcdebac0>,
#   <matplotlib.lines.Line2D at 0x288dcdebd90>],
#  'boxes': [<matplotlib.lines.Line2D at 0x288dcdeb220>],
#  'medians': [<matplotlib.lines.Line2D at 0x288dce030a0>],
#  'fliers': [<matplotlib.lines.Line2D at 0x288dce033a0>],
#  'means': []}

# %% [markdown]
# # Seaborn Boxplot

# %%
#Set theme and style
sns.set_theme(style='darkgrid', palette='twilight')

# %%
sns.boxplot(df['width'])
# Out:
# C:\Users\Aishwarya\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='width'>

# %%
df[df['width'] > 71]
# Out:
#      symboling normalized-losses           make fuel-type body-style  \
# 6            1               158           audi       gas      sedan
# 7            1                 ?           audi       gas      wagon
# 8            1               158           audi       gas      sedan
# 70          -1                93  mercedes-benz    diesel      sedan
# 71          -1                 ?  mercedes-benz       gas      sedan
# 73           0                 ?  mercedes-benz       gas      sedan
# 74           1                 ?  mercedes-benz       gas    hardtop
# 129          1                 ?        porsche       gas  hatchback
#
#     drive-wheels engine-location  width  height engine-type  engine-size  \
# 6            fwd           front   71.4    55.7         ohc          136
# 7            fwd           front   71.4    55.7         ohc          136
# 8            fwd           front   71.4    55.9         ohc          131
# 70           rwd           front   71.7    56.3         ohc          183
# 71           rwd           front   71.7    56.5        ohcv          234
# 73           rwd           front   71.7    56.7        ohcv          308
# 74           rwd           front   72.0    55.4        ohcv          304
# 129          rwd           front   72.3    50.5       dohcv          203
#
#     horsepower  city-mpg  highway-mpg  price
# 6          110        19           25  17710
# 7          110        19           25  18920
# 8          140        17           20  23875
# 70         123        22           25  31600
# 71         155        16           18  34184
# 73         184        14           16  40960
# 74         184        14           16  45400
# 129        288        17           28  12000

# %%
sns.boxplot(df['price'])
# Out:
# C:\Users\Aishwarya\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='price'>

# %%
len(df[df['price'] > 28000])
# Out:
# 16

# %%
sns.boxplot(df['price'], df['make'])
# Out:
# C:\Users\Aishwarya\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='price', ylabel='make'>

# %% [markdown]
# # Plotly Boxplot

# %%
pe.box(df['width'], orientation='h')
# Out:
# <div>                            <div id="9bf51423-9ba0-4d6c-a66b-ccdcb01a6e4e" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("